# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
 
# create data
x = np.random.rand(15)
print(len(x))
y = x+np.random.rand(15)
print(len(y))
z = x+np.random.rand(15)
print(len(z))

z=z*z

print("After")
print(z)


 
# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, y, s=z*2000, c=x, cmap="Blues", alpha=0.4, edgecolors="grey", linewidth=2)
 
# Add titles (main and on axis)
plt.xlabel("the X axis")
plt.ylabel("the Y axis")
plt.title("A colored bubble plot")

plt.gca().axes.get_yaxis().set_visible(False)
plt.show()
# Out:
# 15
# 15
# 15
# After
# [0.8734147  0.80171252 2.21710962 1.57627068 1.4215412  1.20922957
#  2.51821507 0.89420325 0.31907407 2.22670689 1.34919236 1.27580445
#  0.11138387 3.36782469 0.24200066]

# %%
x = [1, 2, 3]


y = [4, 5, 6]
z = x+np.random.rand(3)
z=z*z
x1 = np.linspace(0, 10, 1000)

figure, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].plot(x, y)
#plt.scatter(x, y, s=z*2000, c=x, cmap="Blues", alpha=0.4, edgecolors="grey", linewidth=2)

axes[0, 1].scatter(x,y,s = z*20, c= x,cmap="Blues", alpha=0.4, edgecolors="grey", linewidth=2)
axes[1, 0].plot(x1, np.cos(x1))
axes[1, 1].plot(range(10))

figure.tight_layout()
